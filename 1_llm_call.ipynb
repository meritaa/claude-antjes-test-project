# %%
from langchain_anthropic import ChatAnthropic
from dotenv import load_dotenv
load_dotenv('c:/Users/merit/.claude/Antjes-Test-Project/.env')
import os

##Show me the current working directory and check if the .env file exists in that directory
#print(f"Current Working Directory: {os.getcwd()}")
#print(f"Does .env file exist? {os.path.exists('.env')}")

#status = load_dotenv("C:/Users/merit/.claude/Antjes-Test-Project/.env")
#print(status)

#myKey = os.getenv("ANTHROPIC_API_KEY")  
#print(myKey)

if os.getenv("ANTHROPIC_API_KEY") is None:
    print("ANTHROPIC_API_KEY is not set in the environment variables.")
else:
    print("ANTHROPIC_API_KEY is set in the environment variables.")
# Out:
# ANTHROPIC_API_KEY is set in the environment variables.

# %%
llm = ChatAnthropic(model="claude-haiku-4-5-20251001")
response = llm.invoke("Give me the code to create a pandas dataframe with 3 columns and 5 rows")
response.content
# Out:
# "# Here's a simple example:\n\n```python\nimport pandas as pd\n\ndf = pd.DataFrame({\n    'Column1': [1, 2, 3, 4, 5],\n    'Column2': ['A', 'B', 'C', 'D', 'E'],\n    'Column3': [10.5, 20.3, 15.7, 25.1, 30.2]\n})\n\nprint(df)\n```\n\n**Output:**\n```\n   Column1 Column2  Column3\n0        1       A     10.5\n1        2       B     20.3\n2        3       C     15.7\n3        4       D     25.1\n4        5       E     30.2\n```\n\nYou can customize the column names and data types as needed. Other ways to create a DataFrame:\n\n**Using lists:**\n```python\ndf = pd.DataFrame([[1, 'A', 10.5],\n                   [2, 'B', 20.3],\n                   [3, 'C', 15.7],\n                   [4, 'D', 25.1],\n                   [5, 'E', 30.2]],\n                  columns=['Column1', 'Column2', 'Column3'])\n```\n\n**Using numpy:**\n```python\nimport numpy as np\n\ndf = pd.DataFrame(np.random.rand(5, 3), columns=['Column1', 'Column2', 'Column3'])\n```"
